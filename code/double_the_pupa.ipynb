# %%
import os
import pandas as pd

from adversarial import Pacifist, AdversarialWordLevel, AdversarialAlignments

from utils import load_config

config = load_config()

# %%
for base_language in config['languages']:
    base_path = f'results/{base_language}/'

    if not os.path.exists(base_path):
        os.mkdir(base_path)

    other_languages = list(config['languages'])
    other_languages.remove(base_language)

    # WORD LEVEL

    results = {}

    results['No attack'] = Pacifist(base_language=base_language).attack_test()
    results['Word level [ALL]'] = AdversarialWordLevel(base_language=base_language).attack_test()

    for language in other_languages:
        results[f'Word level [{language}]'] = AdversarialWordLevel(base_language=base_language, languages=[language]).attack_test()

    pd.DataFrame.from_dict(results).to_csv(base_path + f'word_level_{config["model_name"]}.csv')

    # ALIGNMENTS

    results = {}

    results['No attack'] = Pacifist(base_language=base_language).attack_test()

    results['Alignments [ALL]'] = AdversarialAlignments(base_language=base_language).attack_test()

    for language in other_languages:
        results[f'Alignments [{language}]'] = AdversarialAlignments(base_language=base_language, languages=[language]).attack_test()

    pd.DataFrame.from_dict(results).to_csv(base_path + f'alignments_{config["model_name"]}.csv')
# Out:
# GENERATING ADVERSARIAL EXAMPLES: 100%|██████████| 755/755 [00:00<00:00, 3038.85it/s]
# GENERATING ADVERSARIAL EXAMPLES: 100%|██████████| 755/755 [04:27<00:00,  2.83it/s]
# GENERATING ADVERSARIAL EXAMPLES: 100%|██████████| 755/755 [00:48<00:00, 15.52it/s]
# GENERATING ADVERSARIAL EXAMPLES: 100%|██████████| 755/755 [00:50<00:00, 15.10it/s]
# GENERATING ADVERSARIAL EXAMPLES: 100%|██████████| 755/755 [00:47<00:00, 15.82it/s]
# GENERATING ADVERSARIAL EXAMPLES: 100%|██████████| 755/755 [00:51<00:00, 14.52it/s]
# GENERATING ADVERSARIAL EXAMPLES: 100%|██████████| 755/755 [00:48<00:00, 15.55it/s]
# GENERATING ADVERSARIAL EXAMPLES: 100%|██████████| 755/755 [00:50<00:00, 14.90it/s]
# GENERATING ADVERSARIAL EXAMPLES: 100%|██████████| 755/755 [00:00<00:00, 3020.28it/s]
# GENERATING ADVERSARIAL EXAMPLES: 100%|██████████| 755/755 [04:35<00:00,  2.75it/s]
# GENERATING ADVERSARIAL EXAMPLES: 100%|██████████| 755/755 [00:51<00:00, 14.53it/s]
# GENERATING ADVERSARIAL EXAMPLES: 100%|██████████| 755/755 [00:53<00:00, 14.06it/s]
# GENERATING ADVERSARIAL EXAMPLES: 100%|██████████| 755/755 [00:53<00:00, 14.15it/s]
# GENERATING ADVERSARIAL EXAMPLES: 100%|██████████| 755/755 [00:43<00:00, 17.19it/s]
# GENERATING ADVERSARIAL EXAMPLES: 100%|██████████| 755/755 [00:53<00:00, 14.07it/s]
# GENERATING ADVERSARIAL EXAMPLES: 100%|██████████| 755/755 [00:50<00:00, 15.06it/s]
# GENERATING ADVERSARIAL EXAMPLES: 100%|██████████| 755/755 [00:00<00:00, 2879.97it/s]
# GENERATING ADVERSARIAL EXAMPLES: 100%|██████████| 755/755 [03:55<00:00,  3.20it/s]
# GENERATING ADVERSARIAL EXAMPLES:  65%|██████▍   | 487/755 [00:29<00:15, 16.77it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-233a5e7c74b0> in <module>
#      16
#      17     for language in other_languages:
# ---> 18         results[f'Word level [{language}]'] = AdversarialWordLevel(base_language=base_language, languages=[language]).attack_test()
#      19
#      20     pd.DataFrame.from_dict(results).to_csv(base_path + f'word_level_{config["model_name"]}.csv')
#
# ~/.local/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~/diploma/code/adversarial.py in attack_test(self)
#      62                 tokens, slot_labels = tokenize_and_preserve_labels(
#      63                     self.model.tokenizer,
# ---> 64                     ' '.join(self.attack(x, y_slots, y_intent)),
#      65                     y_slots,
#      66                     self.slot2idx
#
# ~/diploma/code/adversarial.py in attack(self, x, y_slots, y_intent)
#     173
#     174         for pos in self.rng.permutation(len(x)):
# --> 175             candidates, losses = self.get_candidates(x, y_slots, y_intent, pos)
#     176
#     177             if candidates and current_loss < np.max(losses):
#
# ~/diploma/code/adversarial.py in get_candidates(self, x, y_slots, y_intent, pos)
#     191                 xc[pos] = token
#     192
# --> 193                 losses.append(self.calculate_loss(xc, y_slots, y_intent))
#     194                 candidates.append(token)
#     195             except KeyError:
#
# ~/.local/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~/diploma/code/adversarial.py in calculate_loss(self, x, y_slots, y_intent)
#     121         )
#     122
# --> 123         loss = self.model(input_ids, intent, slot_labels, attention_mask)
#     124
#     125         return loss[0].cpu().item()
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/diploma/code/model.py in forward(self, input_ids, intent_label_ids, slot_labels_ids, attention_mask)
#      61
#      62     def forward(self, input_ids, intent_label_ids, slot_labels_ids, attention_mask=None):
# ---> 63         outputs = self.model(input_ids, attention_mask=attention_mask)
#      64
#      65         sequence_output = outputs[0]
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/.local/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     964             past_key_values_length=past_key_values_length,
#     965         )
# --> 966         encoder_outputs = self.encoder(
#     967             embedding_output,
#     968             attention_mask=extended_attention_mask,
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/.local/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     565                 )
#     566             else:
# --> 567                 layer_outputs = layer_module(
#     568                     hidden_states,
#     569                     attention_mask,
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/.local/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     453         # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     454         self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 455         self_attention_outputs = self.attention(
#     456             hidden_states,
#     457             attention_mask,
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/.local/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     393             output_attentions,
#     394         )
# --> 395         attention_output = self.output(self_outputs[0], hidden_states)
#     396         outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#     397         return outputs
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/.local/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, input_tensor)
#     343
#     344     def forward(self, hidden_states, input_tensor):
# --> 345         hidden_states = self.dense(hidden_states)
#     346         hidden_states = self.dropout(hidden_states)
#     347         hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      92
#      93     def forward(self, input: Tensor) -> Tensor:
# ---> 94         return F.linear(input, self.weight, self.bias)
#      95
#      96     def extra_repr(self) -> str:
#
# ~/.local/lib/python3.8/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1751     if has_torch_function_variadic(input, weight):
#    1752         return handle_torch_function(linear, (input, weight), input, weight, bias=bias)
# -> 1753     return torch._C._nn.linear(input, weight, bias)
#    1754
#    1755
#
# KeyboardInterrupt:
